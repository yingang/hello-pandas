# %%
import numpy as np

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(10))
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
from numpy.random import randn

# %%
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
fig, axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000202182196A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020218245A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020218287048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000202182B45F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000202182E6BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020218323128>]],
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)

# %%
plt.subplots_adjust(wspace=0, hspace=0)
